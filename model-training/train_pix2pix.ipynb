# %%
# !git clone https://github.com/allexeyj/instruction-tuned-sd  > /dev/null
# %cd instruction-tuned-sd
# !pip install -r requirements.txt  > /dev/null
# !pip install xformers bitsandbytes > /dev/null
# Out:
# Cloning into 'instruction-tuned-sd'...
# remote: Enumerating objects: 197, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 197 (delta 19), reused 15 (delta 15), pack-reused 173
# Receiving objects: 100% (197/197), 63.36 KiB | 12.67 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# /kaggle/working/instruction-tuned-sd
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# keras-cv 0.8.2 requires keras-core, which is not installed.
# ...

# %%
from huggingface_hub import login


login("TOP_SECRET")
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !wandb login TOP_SECRET
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !accelerate launch --mixed_precision="fp16" finetune_instruct_pix2pix.py \
  --pretrained_model_name_or_path="timbrooks/instruct-pix2pix" \
  --dataset_name="Alexator26/703_stickers_improved_v1" \ #cringe username
  --resolution=512 --random_flip \
  --train_batch_size=2 --gradient_accumulation_steps=4 \
  --max_train_steps=2109 \
  --checkpointing_steps=2109 --checkpoints_total_limit=1 \
  --learning_rate=5e-05 --lr_warmup_steps=0 \
  --mixed_precision=fp16 \
  --val_image_url="https://lh3.googleusercontent.com/m9yut9P5WkCn1w7PBR7Fx44gzVNDeHiXxGT00cWtnrmyHCp77bN3-F0TReNzpiFJ6KTtoRr6PCDXGJG25zy5Dg" \
  --validation_prompt="Modify the image to be a sticker." \
  --seed=42 \
  --output_dir="stickerization-finetuned" \
  --report_to=wandb \
  --use_8bit_adam
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/opt/conda/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# /opt/conda/lib/python3.10/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /opt/conda/lib/python3.10/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# ...
